# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np

data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([  53,   36,  105,   26,   50,  118,  103,   78,   -7,  -72,   19,
#          12,  103,    8,   50,   60,  -30,   44,   65,   93,  122,   86,
#         173,  146,  148,   88,   -9, -103, -182, -140, -102,  -48,  -46,
#           8,  -90, -144,  -81, -180, -260, -352, -372, -359, -360, -412,
#        -463, -429, -347, -424, -375, -377], dtype=int32)

# %%
plt.plot(range(50), data, 'r')
mpl.rcParams['axes.unicode_minus'] = False
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5,0,'시간(분)')

# %%
print('버전: ',mpl.__version__)
print('설치 위치: ', mpl.__file__)
print('설정 위치: ', mpl.get_configdir())
print('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  2.1.2
# 설치 위치:  C:\Users\soul9\anaconda\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\soul9\.matplotlib
# 캐시 위치:  C:\Users\soul9\.matplotlib

# %%
print('설정 파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정 파일 위치:  C:\Users\soul9\anaconda\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

print(len(font_list))
# Out:
# 717

# %%
font_list_mac = fm.OSXInstalledFonts()
print(len(font_list_mac))
# Out:
# 0

# %%
font_list[:10]
# Out:
# ['C:\\Windows\\Fonts\\H2HDRM.TTF',
#  'c:\\windows\\fonts\\calistb.ttf',
#  'c:\\windows\\fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  'C:\\Windows\\Fonts\\MAGNETOB.TTF',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  'c:\\windows\\fonts\\tccm____.ttf',
#  'c:\\windows\\fonts\\tccb____.ttf',
#  'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  'C:\\Windows\\Fonts\\georgiab.ttf']

# %%
f = [f.name for f in fm.fontManager.ttflist]
print(len(font_list))
f[:10]
# Out:
# 717
# ['cmr10',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'DejaVu Serif Display',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono']

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Gothic' in f.name]
# Out:
# [('HYGothic-Medium', 'C:\\Windows\\Fonts\\H2GTRM.TTF'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHIC.TTF'),
#  ('Franklin Gothic Medium Cond', 'C:\\Windows\\Fonts\\FRAMDCN.TTF'),
#  ('Franklin Gothic Heavy', 'c:\\windows\\fonts\\frahv.ttf'),
#  ('Century Gothic', 'c:\\windows\\fonts\\gothic.ttf'),
#  ('Century Gothic', 'c:\\windows\\fonts\\gothici.ttf'),
#  ('Franklin Gothic Demi', 'c:\\windows\\fonts\\fradmit.ttf'),
#  ('Franklin Gothic Medium Cond', 'c:\\windows\\fonts\\framdcn.ttf'),
#  ('Malgun Gothic', 'c:\\windows\\fonts\\malgunbd.ttf'),
#  ('Franklin Gothic Demi', 'C:\\Windows\\Fonts\\FRADM.TTF'),
#  ('Franklin Gothic Book', 'c:\\windows\\fonts\\frabkit.ttf'),
#  ('Franklin Gothic Medium', 'C:\\Windows\\Fonts\\framdit.ttf'),
#  ('Franklin Gothic Book', 'C:\\Windows\\Fonts\\FRABKIT.TTF'),
#  ('Showcard Gothic', 'C:\\Windows\\Fonts\\SHOWG.TTF'),
#  ('Franklin Gothic Demi Cond', 'C:\\Windows\\Fonts\\FRADMCN.TTF'),
#  ('Franklin Gothic Book', 'c:\\windows\\fonts\\frabk.ttf'),
#  ('Copperplate Gothic Light', 'C:\\Windows\\Fonts\\COPRGTL.TTF'),
#  ('Malgun Gothic', 'c:\\windows\\fonts\\malgunsl.ttf'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHICB.TTF'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHICBI.TTF'),
#  ('Malgun Gothic', 'c:\\windows\\fonts\\malgun.ttf'),
#  ('Franklin Gothic Medium', 'c:\\windows\\fonts\\framd.ttf'),
#  ('MJemokGothic', 'C:\\Windows\\Fonts\\MK.TTF'),
#  ('HYGothic-Medium', 'c:\\windows\\fonts\\h2gtrm.ttf'),
#  ('HYGothic-Extra', 'C:\\Windows\\Fonts\\H2GTRE.TTF'),
#  ('Copperplate Gothic Bold', 'c:\\windows\\fonts\\coprgtb.ttf'),
#  ('Franklin Gothic Book', 'C:\\Windows\\Fonts\\FRABK.TTF'),
#  ('Franklin Gothic Demi', 'C:\\Windows\\Fonts\\FRADMIT.TTF'),
#  ('Century Gothic', 'c:\\windows\\fonts\\gothicbi.ttf'),
#  ('Franklin Gothic Heavy', 'C:\\Windows\\Fonts\\FRAHVIT.TTF'),
#  ('Franklin Gothic Heavy', 'C:\\Windows\\Fonts\\FRAHV.TTF'),
#  ('MJemokGothic', 'c:\\windows\\fonts\\mk.ttf'),
#  ('Copperplate Gothic Light', 'c:\\windows\\fonts\\coprgtl.ttf'),
#  ('Showcard Gothic', 'c:\\windows\\fonts\\showg.ttf'),
#  ('Franklin Gothic Demi', 'c:\\windows\\fonts\\fradm.ttf'),
#  ('Franklin Gothic Heavy', 'c:\\windows\\fonts\\frahvit.ttf'),
#  ('Century Gothic', 'C:\\Windows\\Fonts\\GOTHICI.TTF'),
#  ('Franklin Gothic Demi Cond', 'c:\\windows\\fonts\\fradmcn.ttf'),
#  ('Copperplate Gothic Bold', 'C:\\Windows\\Fonts\\COPRGTB.TTF'),
#  ('Century Gothic', 'c:\\windows\\fonts\\gothicb.ttf'),
#  ('HYGothic-Extra', 'c:\\windows\\fonts\\h2gtre.ttf')]

# %% [markdown]
# # 1. FontProperties 사용

# %%
path = 'C:\\Windows\\Fonts\\H2GTRM.TTF'
fontprop = fm.FontProperties(fname=path, size=18)

plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이', fontproperties=fontprop)
plt.ylabel('주식 가격', fontproperties=fontprop)
plt.xlabel('시간(분)', fontproperties=fontprop)
plt.show()

# %% [markdown]
# # 2. matplotlib.rcParams[]으로 전역 글꼴 설정

# %%
print('# 설정되어 있는 폰트 사이즈')
print(plt.rcParams['font.size'])
print('#설정되어있는 폰트 글꼴')
print (plt.rcParams['font.family'] )
# Out:
# # 설정되어 있는 폰트 사이즈
# 10.0
# #설정되어있는 폰트 글꼴
# ['sans-serif']

# %%
print('serif 세리프가 있는 폰트--------')
print (plt.rcParams['font.serif']) 
print('sans-serif 세리프가 없는 폰트 --------')
print (plt.rcParams['font.sans-serif']) 
print('monospace 고정폭 글꼴--------')
print (plt.rcParams['font.monospace'])
# Out:
# serif 세리프가 있는 폰트--------
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# sans-serif 세리프가 없는 폰트 --------
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# monospace 고정폭 글꼴--------
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %%
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 16
plt.rcParams["figure.figsize"] = (14,4)

# %%
plt.plot(range(50), data, 'r')
plt.plot('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('seaborn-pastel')
plt.show()

# %% [markdown]
# # -rcParams 대신 FontProperties 와 plt.rc를 사용하는 방법

# %%
path = 'c:\\windows\\fonts\\malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
print(font_name)
plt.rc('font', family=font_name)

fig, ax = plt.subplots()
ax.plot(data)
ax.set_title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('ggplot')
plt.show()
# Out:
# Malgun Gothic

# %% [markdown]
# # rcParams 를 설정 파일에 직접 적어주는 방법 - 모든 노트북에 적용

# %%
print('설정 파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정 파일 위치:  C:\Users\soul9\anaconda\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('숫자 분포도 보기')
plt.show()
